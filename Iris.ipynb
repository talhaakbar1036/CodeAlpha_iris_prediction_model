# %% [markdown]
# <a href="https://colab.research.google.com/github/talhaakbar1036/CodeAlpha_iris_prediction_model/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Essential libraries

# %%
import pandas as pd
import n
